# %% [markdown]
# # 💸 Paytm Data Analysis

# %% [markdown]
# ![img](https://th.bing.com/th/id/R.576f2e5988a69151f2cc50449b9fdeb8?rik=o6zy4t%2f0x%2fZU7A&riu=http%3a%2f%2ftrak.in%2fwp-content%2fuploads%2f2017%2f09%2fPaytm-Payments-Bank-Banner.jpg&ehk=hZu8Vbh79vsqxDuRdHwdZD0h00BdewRCIEkOlcJCf%2f0%3d&risl=&pid=ImgRaw&r=0)

# %% [markdown]
# **Paytm**, short for "Pay Through Mobile", is a leading financial technology company based in India. Founded in 2010 by Vijay Shekhar Sharma under One97 Communications, it's headquartered in Noida, Uttar Pradesh. Paytm specializes in digital payments and financial services, providing a platform for users to transfer money into an integrated wallet via debit cards, credit cards, and online banking. This platform has revolutionized the way India makes payments, from everyday retail purchases to larger financial transactions. Paytm's services extend beyond digital wallets, offering online shopping, bill payments, ticket booking, and even investment opportunities. It's a prime example of how fintech can transform financial accessibility and convenience.

# %% [markdown]
# # 💸 TABLE OF CONTENTS
#
# 1. [About the Dataset](#💸-About-the-Dataset)
# 2. [Objective](#💸-Objective)
# 3. [Research Questions](#💸-Research-Questions)
# 4. [Importing Libraries](#💸-Importing-Libraries)
# 5. [Loading the Dataset](#💸-Loading-the-Dataset)
# 6. [Descriptive Data Analysis and Cleaning](#💸-Descriptive-Data-Analysis-and-Cleaning)
# 7. [Exploratory Data Analysis and Visualizations](#💸-Exploratory-Data-Analysis-and-Visualizations)
# 8. [Summary and Conclusion](#💸-Summary-and-Conclusion)

# %% [markdown]
# # 💸 About the Dataset
#
# This dataset contains Paytm Revenue, Users, Transactions listed operational metrics and revenue of Indian Payment App 'Paytm' from June, 2020 to March, 2023.
#
# Note: All money figures are in INR (Indian National Rupee).
#
# 1 Cr is 1 Crore in Indian Number System and 1 Cr is equivalent to 10 million. 1 Lakh is equal to 100 thousand.
#
# ## **Data Dictionary**:
#
# | Columns | Description |
# | --- | --- |
# |Gross Merchandise Value (GMV) :| Value of total payments made to merchants through Paytm app. It is in INR Lac Cr (100,000 Crores).|
# |Merchant Transactions :| Total number of Transactions made to merchant through Paytm App. It is in millions.|
# |Total Transaction :| Total number of Merchant Transactions and Non-merchant transactions (person to person). It is in millions.|
# |Average Monthly Transacting Users (MTU) :| Unique merchants that are listed for receiving a transaction through Paytm QR or a Paytm issued device. It is in millions.|
# |Registered Merchants (end of period) :| Number of Registered merchants account in millions.|
# |Payment Devices (cumulative, end of period):| Total number of Paytm POS devices and Soundbox deployed at our in-store merchants. It is in millions.|
# |Volume of Loan Distributed :| Total volume of loans distributed to users. It is in Thousands.
# |Postpaid Loans:| Volume of loans distributed to postpaid users   |
# |Personal Loans:| Volume of loans distributed to personal users  |
# |Merchant Loans:|Volume of loans distributed to merchants.|
# |Value of loans distributed :| Value of loans distributed to users in INR Cr (Crore).|
# |Postpaid Loans.1 :| Value of loans distributed to postpaid users  |
# |Personal Loans.1 :| Value of loans distributed to personal users  |
# |Merchant Loans.1 :|Value of loans distributed to merchants |
# |Payments Services to Consumers:| Revenue generated from consumers in INR crores.|
# |Payments Services to Merchants:| Revenue generated from merchants in INR crores.  |
# |Other Operating Revenue:| Revenue generated from other sources in INR crores.|
# |Total Payments Revenue: | Total Revenue generated |
# |Payment processing charges:| Payment processing charges is charge paid by Paytm (in INR crores).|
# |Net Payments Margin:| It is subtracted from total revenue to get Net Payments margin in INR crores.|

# %% [markdown]
# # 💸 Objective
#
# The objective of this analysis is to understand the distribution, trends, correlations, and outliers in key financial metrics such as merchandise transactions, loan volumes, processing fees, and revenues. This will provide insights into the financial performance and operational efficiency of the business, guiding strategic decision-making and future planning.

# %% [markdown]
# # 💸 Research Questions
# 1. What is the distribution of ‘Quarterly Merchandise Value Transactions’?
# 2. What is the correlation between ‘Merchant Transaction Vs Merchant Loan Volume’?
# 3. Are there any outliers in the ‘Payment Processing Fees’?
# 4. What is the trend of ‘Loan Volume of Merchants’ over time?
# 5. Which quarter has generated the highest ‘Revenue’?
# 6. Is there a significant difference in ‘Revenue generated from consumers’ over different quarters?
# 7. What is the trend of ‘Personal Loan’ value over time?
# 8. What is the correlation between ‘Payment Revenue’ and ‘Payment Processing Charges’?

# %% [markdown]
# # 💸 Importing Libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
pd.set_option('display.max_columns', None)
plt.style.use('ggplot')

# %% [markdown]
# # 💸 Loading the Dataset

# %%
df = pd.read_csv(r'C:\Users\MEGAMIND\Downloads\paytm\paytm.csv')

# %% [markdown]
# # 💸 Descriptive Data Analysis and Cleaning

# %%
df
# Out:
#          Date   Gross Merchandise Value  Merchant Transactions  \
# 0   01-06-2020                     0.70                    969
# 1   01-09-2020                     0.95                   1232
# 2   01-12-2020                     1.12                   1587
# 3   01-03-2021                     1.27                   2084
# 4   01-06-2021                     1.47                   2287
# 5   01-09-2021                     1.96                   2692
# 6   01-12-2021                     2.50                   3477
# 7   01-03-2022                     2.59                   4142
# 8   01-06-2022                     2.96                   5124
# 9   01-09-2022                     3.18                   5752
# 10  01-12-2022                     3.46                   6284
# 11  01-03-2023                     3.62                   6851
#
#     Total Transactions  Average Monthly Transacting Users (MTU)  \
# 0                 1231                                     39.7
# ...

# %%
df.shape
# Out:
# (12, 21)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 21 columns):
#  #   Column                                       Non-Null Count  Dtype
# ---  ------                                       --------------  -----
#  0   Date                                         12 non-null     object
#  1   Gross Merchandise Value                      12 non-null     float64
#  2   Merchant Transactions                        12 non-null     int64
#  3   Total Transactions                           12 non-null     int64
#  4   Average Monthly Transacting Users (MTU)      12 non-null     float64
#  5   Registered Merchants (end of period)         12 non-null     float64
#  6   Payment Devices (cumulative, end of period)  12 non-null     float64
#  7   Volume of loans distributed                  12 non-null     int64
#  8     Postpaid Loans                             12 non-null     int64
# ...

# %%
# Looking closely at the `Other Operating Revenue` column
df['Other Operating Revenue']
# Out:
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4       -
# 5       -
# 6       -
# 7       -
# 8       -
# 9      15
# 10     44
# 11     25
# Name: Other Operating Revenue, dtype: object

# %%
# Dropping the `Other Operating Revenue` column as it contains many missings values
df.drop(['Other Operating Revenue'], axis=1, inplace=True)

# %%
df.columns
# Out:
# Index(['Date ', 'Gross Merchandise Value', 'Merchant Transactions',
#        'Total Transactions', 'Average Monthly Transacting Users (MTU)',
#        'Registered Merchants (end of period)',
#        'Payment Devices (cumulative, end of period)',
#        'Volume of loans distributed', '  Postpaid Loans', '  Personal Loans',
#        '  Merchant Loans', 'Value of loans distributed', '  Postpaid Loans.1',
#        '  Personal Loans.1', '  Merchant Loans.1',
#        'Payments Services to Consumers', 'Payments Services to Merchants',
#        'Total Payments Revenue', 'Payment processing charges',
#        'Net Payments Margin'],
#       dtype='object')

# %%
# Renaming the columns
df = df.rename(columns={'Date ':'date', 
                        'Gross Merchandise Value':'gross_merc_value', 
                        'Merchant Transactions':'merchant_trans',
                        'Total Transactions':'total_trans', 
                        'Average Monthly Transacting Users (MTU)':'MTU',
                        'Registered Merchants (end of period)':'reg_merchant',
                        'Payment Devices (cumulative, end of period)': 'payment_devices',
                        'Volume of loans distributed':'total_loan_volume', 
                        '  Postpaid Loans':'postpaid_loan_volume', 
                        '  Personal Loans':'personal_loan_volume',
                        '  Merchant Loans':'merchant_loan_volume', 
                        'Value of loans distributed':'Total_loan_value', 
                        '  Postpaid Loans.1':'postpaid_loan_value',
                        '  Personal Loans.1':'personal_loan_value', 
                        '  Merchant Loans.1':'merchant_loan_value',
                        'Payments Services to Consumers':'ps_consumers', 
                        'Payments Services to Merchants':'ps_merchants',
                        'Total Payments Revenue':'total_pr', 
                        'Payment processing charges':'pay_processing_charge',
                        'Net Payments Margin':'net_pay_margin'})

# %%
df.describe()
# Out:
#        gross_merc_value  merchant_trans  total_trans        MTU  reg_merchant  \
# count         12.000000       12.000000    12.000000  12.000000     12.000000
# mean           2.148333     3540.083333  4316.333333  62.716667     24.641667
# std            1.035127     2054.281403  2455.174252  17.134061      5.277820
# min            0.700000      969.000000  1231.000000  39.700000     17.000000
# 25%            1.232500     1959.750000  2428.000000  49.575000     20.825000
# 50%            2.230000     3084.500000  3791.000000  60.900000     23.950000
# 75%            3.015000     5281.000000  6315.750000  76.025000     28.600000
# max            3.620000     6851.000000  8350.000000  89.900000     33.500000
#
#        payment_devices  total_loan_volume  postpaid_loan_volume  \
# count        12.000000          12.000000             12.000000
# mean          2.500000        4826.583333           4692.750000
# std           2.303357        4302.093052           4163.871562
# ...

# %%
df.dtypes
# Out:
# date                      object
# gross_merc_value         float64
# merchant_trans             int64
# total_trans                int64
# MTU                      float64
# reg_merchant             float64
# payment_devices          float64
# total_loan_volume          int64
# postpaid_loan_volume       int64
# personal_loan_volume       int64
# merchant_loan_volume       int64
# Total_loan_value           int64
# postpaid_loan_value        int64
# personal_loan_value        int64
# merchant_loan_value        int64
# ps_consumers             float64
# ps_merchants             float64
# total_pr                 float64
# pay_processing_charge    float64
# net_pay_margin           float64
# dtype: object

# %%
# Check for NaN values
df.isna().sum()
# Out:
# date                     0
# gross_merc_value         0
# merchant_trans           0
# total_trans              0
# MTU                      0
# reg_merchant             0
# payment_devices          0
# total_loan_volume        0
# postpaid_loan_volume     0
# personal_loan_volume     0
# merchant_loan_volume     0
# Total_loan_value         0
# postpaid_loan_value      0
# personal_loan_value      0
# merchant_loan_value      0
# ps_consumers             4
# ps_merchants             4
# total_pr                 4
# pay_processing_charge    4
# net_pay_margin           4
# dtype: int64

# %%
# Check for duplicated values
df.duplicated().sum()
# Out:
# 0

# %%
# Final shape
df.shape
# Out:
# (12, 20)

# %%
df.head()
# Out:
#          date  gross_merc_value  merchant_trans  total_trans   MTU  \
# 0  01-06-2020              0.70             969         1231  39.7
# 1  01-09-2020              0.95            1232         1578  43.0
# 2  01-12-2020              1.12            1587         2038  47.1
# 3  01-03-2021              1.27            2084         2558  50.4
# 4  01-06-2021              1.47            2287         2785  50.4
#
#    reg_merchant  payment_devices  total_loan_volume  postpaid_loan_volume  \
# 0          17.0              0.0                 23                    20
# 1          18.5              0.3                349                   332
# 2          20.0              0.6                881                   851
# 3          21.1              0.8               1381                  1355
# 4          21.8              0.9               1433                  1413
#
#    personal_loan_volume  merchant_loan_volume  Total_loan_value  \
# ...

# %%
df['date']
# Out:
# 0     01-06-2020
# 1     01-09-2020
# 2     01-12-2020
# 3     01-03-2021
# 4     01-06-2021
# 5     01-09-2021
# 6     01-12-2021
# 7     01-03-2022
# 8     01-06-2022
# 9     01-09-2022
# 10    01-12-2022
# 11    01-03-2023
# Name: date, dtype: object

# %% [markdown]
# # 💸 Exploratory Data Analysis and Visualizations

# %% [markdown]
# 1. What is the distribution of ‘Quarterly Merchandise Value Transactions’?

# %%
plt.figure(figsize=(20,10))
sns.barplot(data = df, x='date', y='gross_merc_value', palette='RdYlGn_r')
plt.title('DISTRIBUTION OF QUARTERLY MERCHANDISE VALUE TRANSACTIONS', fontweight='bold', size=20)
plt.xlabel('Date', size=18)
plt.ylabel('Gross Merchandise Value(in Lac Cr)', size=18)
plt.xticks(size=13)
plt.yticks(size=13)
plt.show()

# %% [markdown]
# - There is a gradual increase in the `Gross Merchandise Value` over every quarter.

# %% [markdown]
# 2. What is the correlation between ‘Payment Volume’ and ‘Merchant Loans’?

# %%
correlation = df[['merchant_trans' ,'merchant_loan_volume']].corr()
sns.heatmap(correlation, annot=True, cmap='coolwarm')
plt.title('Correlation between Merchant Transaction Vs Merchant Loan Volume')
plt.show()

# %% [markdown]
# - A correlation of `0.93` indicates a very strong positive linear relationship between two variables. It suggests that when the transaction volume for a merchant increases, the loan volume for the merchant also tends to increase, and vice versa.

# %% [markdown]
# 3. Are there any outliers in the ‘Payment Processing Charges’?

# %%
# Plot the boxplot of the 'Payment processing charges' column
sns.boxplot(y='pay_processing_charge', data=df)
plt.title('Boxplot of Payment Processing Charges')
plt.show()

# %%
df['pay_processing_charge'].value_counts()
# Out:
# -527.0    1
# -670.0    1
# -783.0    1
# -774.0    1
# -694.0    1
# -746.0    1
# -738.0    1
# -780.0    1
# Name: pay_processing_charge, dtype: int64

# %%
# removing outlier
df = df[df['pay_processing_charge'] < -527.0]

# %%
sns.boxplot(y='pay_processing_charge', data=df)
# Out:
# <Axes: ylabel='pay_processing_charge'>

# %%
df.columns
# Out:
# Index(['date', 'gross_merc_value', 'merchant_trans', 'total_trans', 'MTU',
#        'reg_merchant', 'payment_devices', 'total_loan_volume',
#        'postpaid_loan_volume', 'personal_loan_volume', 'merchant_loan_volume',
#        'Total_loan_value', 'postpaid_loan_value', 'personal_loan_value',
#        'merchant_loan_value', 'ps_consumers', 'ps_merchants', 'total_pr',
#        'pay_processing_charge', 'net_pay_margin'],
#       dtype='object')

# %% [markdown]
# 4. What is the trend of ‘Loan Volume of Merchants’ over time?

# %%
plt.figure(figsize=(16,8))
sns.lineplot(data=df, x='date', y='merchant_loan_volume')
plt.title('VOLUME TREND OF MERCHANT LOANS', size=20, fontweight='bold')
plt.xlabel('Date', size=15)
plt.ylabel('Merchant loan volume', size=15)
plt.show()

# %% [markdown]
# - The `merchant loan volume` increases from `01-06-2020` to `01-12-2020`, then there is a decline from `01-12-2020` to `01-06-2021`. From `01-06-2021` there is consistent increase of `merchant loan volume` overall.

# %% [markdown]
# 5. Which quarter has generated the highest ‘Revenue’?

# %%
plt.figure(figsize=(10,6))
sns.barplot(data=df, x='date', y='total_pr', palette='viridis')
plt.title('HIGHEST TOTAL PAYMENTS REVENUE', size=20, fontweight='bold')
plt.xlabel('Quarter', size=15)
plt.ylabel('Total Payments Revenue (in millions)', size=15)
plt.show()

# %% [markdown]
# - The Quarter `01-03-2023` generated the highest revenue.

# %% [markdown]
# 6. Is there a significant difference in ‘Revenue generated from consumers’ over different quarters?

# %%
plt.figure(figsize=(10,6))
sns.barplot(data=df, x='date', y='ps_consumers', palette='mako')
plt.title('QUARTERLY REVENUE GENERATED FROM CONSUMERS', size=20, fontweight='bold')
plt.xlabel('Quarter', size=15)
plt.ylabel('Revenue generated from consumers (in crores)', size=15)
plt.show()

# %% [markdown]
# - The quarter `01-09-2022` generated the highest revenue from comsumers.

# %% [markdown]
# 7. What is the trend of ‘Personal Loan’ value over time?

# %%
plt.figure(figsize=(20,8))
sns.lineplot(data=df, x='date', y='personal_loan_value', color='green')
plt.title('TREND OF PERSONAL LOAN VALUE', size=20, fontweight='bold')
plt.xlabel('Quarter', size=15)
plt.ylabel('Personal loan value (in crores)', size=15)
plt.show()

# %% [markdown]
# - Trend: The green line shows a steady increase in personal loan value over time.

# %% [markdown]
# 8. What is the correlation between ‘Payment Revenue’ and ‘Payment Processing Charges’?

# %%
# find correlation between `total payment revenue` and `payment processing charges`
correlation = df[['total_pr', 'pay_processing_charge']].corr()
sns.heatmap(correlation, annot=True, cmap='coolwarm')
plt.title('Correlation between Total Payment Revenue Vs Payment Processing Charges')
plt.show()

# %% [markdown]
# - A correlation of `-0.77` between `total payment revenue` and `payment processing charges` indicates a strong negative relationship between these two variables. This means that as `total payment revenue` increases, `payment processing charges` tend to decrease, and vice versa.

# %% [markdown]
# # 💸 Summary and Conclusion

# %% [markdown]
# ### INSIGHTS -
# 1. There is a gradual increase in the `Gross Merchandise Value` over every quarter.
# 2. A correlation between `merchant transactions` Vs `merchant loan volume` of 0.93 indicates a very strong positive linear relationship between two variables. It suggests that when the transaction volume for a merchant increases, the loan volume for the merchant also tends to increase, and vice versa.
# 3. Trend: The red line, `merchant loan volume` increases from `01-06-2020` to `01-12-2020`, then there is a decline from `01-12-2020` to `01-06-2021`. From `01-06-2021` there is consistent increase of `merchant loan volume` overall.
# 4. The Quarter 01-03-2023 generated the highest total revenue.
# 5. The quarter 01-09-2022 generated the highest revenue from comsumers.
# 6. Trend: The green line shows a steady increase in `personal loan value` over time.
# 7. A correlation of `-0.77` between `total payment revenue` and `payment processing charges` indicates a strong negative relationship between these two variables. This means that as `total payment revenue` increases, `payment processing charges` tend to decrease, and vice versa.

# %% [markdown]
# # 💸 THE END
