# %% [markdown]
# # 🏏 ICC MEN'S CRICKET WORLD CUP 2023

# %% [markdown]
# ![img](https://img.cricketworld.com/images/f-127075/icc-cricket-world-cup-2023-logo-.jpg)

# %% [markdown]
# The 2023 **ICC Men's Cricket World Cup** was a grand event hosted by India. The tournament ran from October 5 to November 19, 2023, and saw ten national teams compete in a series of One Day International (ODI) matches. The final was held at the Narendra Modi Stadium in Ahmedabad, where Australia clinched their sixth World Cup title by defeating India.
#
# The tournament was marked by outstanding performances. Indian cricket star Virat Kohli was named the Player of the Tournament and also scored the most runs. Indian bowler Mohammed Shami led in wickets. The event set a new record for attendance, with over 1.25 million spectators.
#
# The top eight teams qualified for the 2025 ICC Champions Trophy. This World Cup was a celebration of cricket, showcasing the sport's spirit and the extraordinary talent of players from around the globe. It left an indelible mark on the history of cricket.

# %% [markdown]
# # 🏏 TABLE OF CONTENTS
#
# 1. [About the dataset](#🏏-About-the-dataset)
# 2. [Research Questions](#🏏-Research-Questions)
# 3. [Importing Libraries](#🏏-Importing-Libraries)
# 4. [Loading the dataset](#🏏-Loading-the-dataset)
# 5. [Descriptive Data Analysis and Cleaning](#🏏-Descriptive-Data-Analysis-and-Cleaning)
# 6. [Exploratory Data Analysis and Visualizations](#🏏-Exploratory-Data-Analysis-and-Visualizations)
# 7. [Summary and Conclusion](#🏏-Summary-and-Conclusion)

# %% [markdown]
# # 🏏 About the dataset
#
# **Batting dataset available here**
#
# This dataset can be used for a variety of purposes, including:
#
# - **Analyzing individual player performances**: Track each batsman's performance throughout the tournament, identifying strengths, weaknesses, and trends.
# - **Evaluating team strategies**: Compare and contrast batting strategies employed by different teams, gaining insights into their approaches and effectiveness.
#
# Whether you're an avid cricket fan, a data enthusiast, or a researcher in the field of sports analytics, this dataset provides a valuable resource for exploring the intricacies of batting performance in the ICC Cricket World Cup 2023.

# %% [markdown]
# # 🏏 Research Questions
#
# 1. Who are the top 10 players with the highest runs?
# 2. What is the distribution of runs across players?
# 3. Who are the players with the most 4s and 6s?
# 4. What is the correlation between runs and balls?
# 5. What is the average number of runs per dismissal type?
# 6. What is the distribution of minutes played by players?
# 7. Who are the top 10 players who faced the most balls?
# 8. What is the correlation between 4s and 6s?
# 9. What are the number of 4s and 6s of top players?

# %% [markdown]
# # 🏏 Importing Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
pd.set_option('display.max_columns', None)
plt.style.use('ggplot')

# %% [markdown]
# # 🏏 Loading the dataset

# %%
df = pd.read_csv('icc_wc_23_bat.csv')

# %% [markdown]
# # 🏏 Descriptive Data Analysis and Cleaning

# %%
df.head()
# Out:
#          player                  dismissal  runs  balls  minutes  4s  6s  \
# 0  Rohit Sharma               b Madushanka     4      2        2   1   0
# 1  Shubman Gill      c Mendis b Madushanka    92     92      136  11   2
# 2   Virat Kohli    c Nissanka b Madushanka    88     94      139  11   0
# 3  Shreyas Iyer  c Theekshana b Madushanka    82     56       84   3   6
# 4      KL Rahul      c Hemantha b Chameera    21     19       34   2   0
#
#    strike_rate   team   opponent  innings  match_id
# 0       200.00  India  Sri Lanka        1         0
# 1       100.00  India  Sri Lanka        1         0
# 2        93.61  India  Sri Lanka        1         0
# 3       146.42  India  Sri Lanka        1         0
# 4       110.52  India  Sri Lanka        1         0

# %%
df.shape
# Out:
# (875, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 875 entries, 0 to 874
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   player       875 non-null    object
#  1   dismissal    875 non-null    object
#  2   runs         875 non-null    int64
#  3   balls        875 non-null    int64
#  4   minutes      875 non-null    int64
#  5   4s           875 non-null    int64
#  6   6s           875 non-null    int64
#  7   strike_rate  875 non-null    float64
#  8   team         875 non-null    object
#  9   opponent     875 non-null    object
#  10  innings      875 non-null    int64
#  11  match_id     875 non-null    int64
# dtypes: float64(1), int64(7), object(4)
# memory usage: 82.2+ KB

# %%
# Generate descriptive statistics
df.describe()
# Out:
#              runs       balls     minutes          4s          6s  \
# count  875.000000  875.000000  875.000000  875.000000  875.000000
# mean    26.773714   29.090286   42.259429    2.558857    0.736000
# std     31.018840   28.579166   41.752733    3.148084    1.490633
# min      0.000000    0.000000    1.000000    0.000000    0.000000
# 25%      5.000000    8.000000   12.000000    0.000000    0.000000
# 50%     15.000000   19.000000   27.000000    1.000000    0.000000
# 75%     39.000000   40.500000   59.000000    4.000000    1.000000
# max    201.000000  143.000000  217.000000   21.000000   11.000000
#
#        strike_rate     innings    match_id
# count   875.000000  875.000000  875.000000
# mean     82.771337    1.459429   23.186286
# std      53.106854    0.498636   13.828329
# min       0.000000    1.000000    0.000000
# 25%      50.000000    1.000000   11.500000
# 50%      80.430000    1.000000   23.000000
# 75%     106.660000    2.000000   35.000000
# ...

# %%
# Check for null values
df.isna().sum()
# Out:
# player         0
# dismissal      0
# runs           0
# balls          0
# minutes        0
# 4s             0
# 6s             0
# strike_rate    0
# team           0
# opponent       0
# innings        0
# match_id       0
# dtype: int64

# %%
# Check for duplicated values
df.duplicated().sum()
# Out:
# 0

# %%
df['dismissal'].unique()
# Out:
# array(['b Madushanka', 'c Mendis b Madushanka', 'c Nissanka b Madushanka',
#        'c Theekshana b Madushanka', 'c Hemantha b Chameera',
#        'run out (Samarawickrama/Mendis)', 'run out (Mendis)', 'not out',
#        'c & b van Beek', 'c Dutt b van Meekeren',
#        'c Saqib Zulfiqar b Ackermann', 'b de Leede',
#        'c Saqib Zulfiqar b Dutt', 'c Edwards b de Leede',
#        'run out (van Meekeren/Ackermann)', 'lbw b de Leede',
#        'st Edwards b Ackermann', 'c Head b Maxwell', 'c Zampa b Starc',
#        'b Cummins', 'c Inglis b Cummins', 'c Inglis b Starc',
#        'c Inglis b Hazlewood', 'lbw b Zampa',
#        'run out (Labuschagne/Cummins)', 'c Livingstone b Rashid',
#        'b Woakes', 'c Stokes b Willey', 'c Wood b Woakes',
#        'c Bairstow b Willey', 'c Woakes b Willey', 'lbw b Rashid',
#        'c Buttler b Wood', 'run out (Buttler)', 'lbw b Rajitha',
#        'b Rajitha', 'c Mendis b Rajitha', 'c Perera b Madushanka',
# ...

# %%
dismissal_types = ['c', 'b', 'lbw', 'st', 'run out']
pattern = '|'.join(dismissal_types)  # Creates a pattern like 'caught|bowled|lbw|stumped|run out'

df['dismissal_type'] = df['dismissal'].str.extract('('+ pattern + ')', expand=False)
df['dismissal_type']
# Out:
# 0        b
# 1        c
# 2        c
# 3        c
# 4        c
#       ...
# 870      c
# 871      b
# 872    lbw
# 873    NaN
# 874      c
# Name: dismissal_type, Length: 875, dtype: object

# %%
df['dismissal_type'].isna().sum()
# Out:
# 147

# %% [markdown]
# # 🏏 Exploratory Data Analysis and Visualizations

# %% [markdown]
# 1. Who are the top 10 players with the highest runs?

# %%
# extract the top players
top_players = df.nlargest(10, 'runs')

# create the bar plot
plt.figure(figsize=(10,6))
sns.barplot(data=top_players, x='runs', y='player', palette='viridis_r')
plt.title('TOP 10 PLAYERS WITH HIGHEST RUNS', size='15', fontweight='bold')
plt.xlabel('Runs')
plt.ylabel('Player Name')
plt.show()

# %% [markdown]
# 2. What is the distribution of runs across top players?

# %%
top_table = top_players[['player','runs']].reset_index(drop=True)
top_table
# Out:
#                   player  runs
# 0          Glenn Maxwell   201
# 1         Mitchell Marsh   177
# 2        Quinton de Kock   174
# 3           David Warner   163
# 4           Devon Conway   152
# 5            Dawid Malan   140
# 6            Travis Head   137
# 7         Daryl Mitchell   134
# 8  Rassie van der Dussen   133
# 9        Mohammad Rizwan   131

# %%
# plot the histogram
plt.figure(figsize=(8,6))
sns.histplot(data=top_players, x='runs', y='player', color='blue')
plt.title('DISTRIBUTION OF RUNS ACROSS TOP PLAYERS', size='15', fontweight='bold')
plt.xlabel('Runs')
plt.ylabel('Player Name')
plt.show()

# %% [markdown]
# 3. Who are the players with the most 4s and 6s?

# %%
# Create a new column of 4s and 6s
df['fours_sixes'] = df['4s'] + df['6s']

# Create barplot
plt.figure(figsize=(8,6))
sns.barplot(y='player', x='fours_sixes', data=df.nlargest(10, 'runs'), palette='RdYlGn_r')
plt.title('PLAYERS WITH MOST 4S AND 6S', size='15', fontweight='bold')
plt.xlabel('Runs')
plt.ylabel('Player Name')
plt.show()

# %% [markdown]
# 4. What is the correlation between runs and balls?

# %%
# find correlation
correlation = df[['runs','balls']].corr()

# plot heatmap
sns.heatmap(correlation, annot=True, cmap='coolwarm')
plt.title('CORRELATION BETWEEN RUNS AND BALLLS')
plt.show()

# %% [markdown]
# - **correlation**: A correlation of `0.93` between `runs` and `balls` in cricket indicates a strong positive relationship. This means that as the number of balls faced by a player increases, the number of runs scored also tends to increase.

# %% [markdown]
# 5. What is the average number of runs per dismissal type?

# %%
# Create barplot
plt.figure(figsize=(10,6))
sns.barplot(data=df, x='dismissal_type', y='runs', ci=None, palette='viridis')
plt.title('AVERAGE RUNS PER DISMISSAL TYPE', fontweight='bold')
plt.ylabel('Runs')
plt.xlabel('Dismissal Type')
plt.show()

# %% [markdown]
# - **Distribution**: The graph shows the distribution of average runs across different types of dismissals. The ‘`c`’ dismissal type i.e `Caught Out` has the highest average runs, while the ‘`st`’ dismissal type i.e `Stumped` has the lowest.

# %% [markdown]
# 6. What is the distribution of minutes played by players?

# %%
plt.figure(figsize=(12,6))
sns.histplot(data=df, x='minutes')
plt.title('DISTRIBUTION OF MINUTES PLAYED BY PLAYERS', fontweight='bold')
plt.xlabel('Minutes')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# - The chart shows the distribution of minutes played by players. The x-axis represents the “Minutes” ranging from 0 to 200, and the y-axis represents the “Count” ranging from 0 to 200. The bars decrease in height as the minutes increase, indicating that fewer players play for longer durations. The highest bar is at 0 minutes with a count of around 175, and the lowest bar is at 200 minutes with a count of around 25. This suggests that most players play for a short duration, while a few players play for longer durations.

# %% [markdown]
# 7. Who are the top 10 players who faced the most balls?

# %%
# Extract the players who faces the most balls
top_balls_faced = df.nlargest(10, 'balls')

balls_faced_table = top_balls_faced[['player', 'balls']].reset_index(drop=True)
balls_faced_table
# Out:
#             player  balls
# 0   Ibrahim Zadran    143
# 1  Quinton de Kock    140
# 2   Mitchell Marsh    132
# 3    Glenn Maxwell    128
# 4   Daryl Mitchell    127
# 5     David Warner    124
# 6      Virat Kohli    121
# 7     Devon Conway    121
# 8  Mohammad Rizwan    121
# 9      Travis Head    120

# %%
# create the bar plot
plt.figure(figsize=(10,6))
sns.barplot(data=top_balls_faced, x='balls', y='player', palette='viridis')
plt.title('TOP 10 PLAYERS WHO FACED THE MOST BALLS', size='15', fontweight='bold')
plt.xlabel('Balls Faced')
plt.ylabel('Player Name')
plt.show()

# %% [markdown]
# 8. What is the correlation between 4s and 6s?

# %%
# Find correlation
cor = df[['4s','6s']].corr()

# Plot heatmap
sns.heatmap(cor, annot=True, cmap='coolwarm')
plt.title('CORRELATION BETWEEN 4S AND 6S')
plt.show()

# %% [markdown]
# - **correlation**: There is a correlation of `0.53`. This suggests that there is a positive correlation of 0.53 between the number of 4s and 6s scored by players. In other words, players who score more 4s are likely to score more 6s, and vice versa.

# %% [markdown]
# 9. What are the number of 4s and 6s of top players?

# %%
# Melt the DataFrame to have '4s' and '6s' in the same column
melted_df = pd.melt(top_players, id_vars='player', value_vars=['4s', '6s'], 
                    var_name='Type', value_name='Count')

# Create the multi-bar chart
plt.figure(figsize=(20,10))
bar_plot = sns.barplot(x='player', y='Count', hue='Type', data=melted_df)
for p in bar_plot.patches:
    bar_plot.annotate(format(p.get_height(), '.1f'), 
                      (p.get_x() + p.get_width() / 2., p.get_height()), 
                      ha = 'center', va = 'center', 
                      xytext = (0, 9), 
                      textcoords = 'offset points')
plt.title('NUMBER OF 4S AND 6S OF TOP 10 PLAYERS', fontweight='bold', size=20)
plt.xlabel('Player Name', size=12)
plt.ylabel('Count', size=12)
plt.show()

# %% [markdown]
# # 🏏 Summary and Conclusion

# %% [markdown]
# ### INSIGHTS -
#
# **1. Who are the top 10 players with the highest runs?**
#
#  - The top 10 players with highest runs are -
#
#   |Player Name | Runs |
#   | --- | --- |
#   |Glenn Maxwell	|201|
#   |Mitchell Marsh	|177|
#   |Quinton de Kock	|174|
#   |David Warner	|163|
#   |Devon Conway	|152|
#   |Dawid Malan	|140|
#   |Travis Head	|137|
#   |Daryl Mitchell	|134|
#   |Rassie van der Dussen	|133|
#   |Mohammad Rizwan	|131|
#
# **2. What is the distribution of runs across top players?**
#
# - **Distribution**: The graph shows that `Glenn Maxwell` has scored the highest number of runs, around 200. On the other hand, `Mohammad Rizwan` has scored around 130 runs.
#
# **3. Who are the players with the most 4s and 6s?**
#
#  - The ranking of the players of most 4s and 6s is exactly the same as the ranking of the players with highest runs.
#
# **4. What is the correlation between runs and balls?**
#
#  -  **correlation**: A correlation of `0.93` between `runs` and `balls` in cricket indicates a strong positive relationship. This means that as the number of balls faced by a player increases, the number of runs scored also tends to increase.
#
# **5. What is the average number of runs per dismissal type?**
#
#  - - **Distribution**: The graph shows the distribution of average runs across different types of dismissals. The ‘`c`’ dismissal type i.e `Caught Out` has the highest average runs, while the ‘`st`’ dismissal type i.e `Stumped` has the lowest.
#
# **6. What is the distribution of minutes played by players?**
#
# - The chart shows the distribution of minutes played by players. The x-axis represents the “Minutes” ranging from 0 to 200, and the y-axis represents the “Count” ranging from 0 to 200. The bars decrease in height as the minutes increase, indicating that fewer players play for longer durations. The highest bar is at 0 minutes with a count of around 175, and the lowest bar is at 200 minutes with a count of around 25. This suggests that most players play for a short duration, while a few players play for longer durations.
#
# **7. Who are the top 10 players who faced the most balls?**
#
#  | Player Name | Balls Faced |
#  | --- | --- |
#  |Ibrahim Zadran	|143|
#  |Quinton de Kock	|140|
#  |Mitchell Marsh	|132|
#  |Glenn Maxwell	|128|
#  |Daryl Mitchell	|127|
#  |David Warner	|124|
#  |Virat Kohli	|121|
#  |Devon Conway	|121|
#  |Mohammad Rizwan	|121|
#  |Travis Head	|120|
#
# **8. What is the correlation between 4s and 6s?**
#
#  - **correlation**: There is a correlation of `0.53`. This suggests that there is a positive correlation of 0.53 between the number of 4s and 6s scored by players. In other words, players who score more 4s are likely to score more 6s, and vice versa.
#
# **9. What are the number of 4s and 6s of top players?**
#
#  | Player Name | 4s | 6s |
#  | --- | --- | --- |
# |Glenn Maxwell	|21	|10|
# |Mitchell Marsh	|17	|9|
# |Quinton de Kock	|15	|7|
# |David Warner	|14	|9|
# |Dewon Conway    |19  |3|
# |Dawid Malan     |16  |5|
# |Travis Head     |15  |4|
# |Daryl Mitchell	|9	|7|
# |Rassie Van Der Dusson  |9 | 5|
# |Muhammed Rizwan|  8|  3|

# %% [markdown]
# # 🏏 THE END
