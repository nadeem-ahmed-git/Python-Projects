# %% [markdown]
# # 🏨Hotel Booking Data Analysis
#
# ![img](https://animalscience.unl.edu/Home/Alumni/AlumniReunion/AdobeStock_99189260-crop.jpg)

# %% [markdown]
# # 🏨TABLE OF CONTENTS
#
# 1. [About the Dataset](#🏨About-the-Dataset)
# 2. [Problem Statement](#🏨Problem-Statement)
# 3. [Assumptions](#🏨Assumptions)
# 4. [Hypothesis](#🏨Hypothesis)
# 5. [Importing Libraries](#🏨Importing-Libraries)
# 6. [Loading the Dataset](#🏨Loading-the-Dataset)
# 7. [Descriptive Data Analysis and Data Cleaning](#🏨Descriptive-Data-Analysis-and-Data-Cleaning)
# 8. [Exploratory Data Analysis and Visualizations](#🏨Exploratory-Data-Analysis-and-Visualizations)
# 9. [Summary and Conclusion](#🏨Summary-and-Conclusion)

# %% [markdown]
# # 🏨About the Dataset
#
# This dataset contains 119390 observations for a City Hotel and a Resort Hotel. Each observation represents a hotel booking between the 1st of July 2015 and 31st of August 2017, including booking that effectively arrived and booking that were canceled.
#
# Contents:
#
# Since this is hotel real data, all data elements pertaining hotel or costumer identification were deleted. Four Columns, `name`, `email`, `phone number` and `credit_card` have been artificially created and added to the dataset.
#
# **Data Dictionary**
#
# | **Column** | **Description**|
# | --- | --- |
# |hotel :| Two hotels are given: Resort Hotel City Hotel|
# |is_canceled :| 1: Canceled 0: Not canceled|
# |cancelation :| 0 as not_canceled 1 as canceled|
# |df_not_canceled_guests :| dataframe with just not_canceled bookings|
# |lead_time :| gap between booking and arrival|
# |arrival_date_year :| arrival year|
# |arrival_date_month :| arrival month|
# |arrival_date_week_number :| arrival week|
# |arrival_date_day_of_month :| arrival date|
# |stays_in_weekend_nights :| count of nights the guests booked the hotel during Sat-Sun|
# |stays_in_week_nights :| count of nights the guests booked the hotel during Mon-Fri|
# |total_stay_nights :| duration of stay including weekend nights and week nights stay|
# |adults :| count of adults|
# |children :| count of children|
# |babies :| count of babies|
# |meal :| meal type (no meal package; BB; HB; FB)|
# |country :| country of guests|
# |df_country_guests_top10 :| top10 countries with most visitors|
# |market_segment :| TA: Travel agents TO: Tour operators|
# |distribution_channel|          |
# |is_repeated_guest :| 1: Yes 0: No|
# |previous_cancellations :| count of previous bookings that were cancelled by the customer before final booking|
# |previous_bookings_not_canceled :| count of no canceled bookings|
# |reserved_room_type :| booked room category|
# |assigned_room_type :| assigned room category|
# |booking_changes :| count of changes made by the customer before final booking|
# |deposit_type :| type of deposit made by the customer|
# |agent :| travel agent id|
# |company :| booking company id|
# |days_in_waiting_list :| count of days the booking was in the waiting list before it was confirmed|
# |customer_type :| Transient Contract Group Transient-party|
# |adr :| average daily rate for the booking|
# |price :| total price spent by a guest entity|
# |required_car_parking_spaces :| count of car parking spaces alloted by the customer|
# |total_of_special_requests :| count of special requests made by the customer|
# |reservation_status status :| of reservation|
# |reservation_status_date :| date corresponding to status of reservation|

# %% [markdown]
# # 🏨Problem Statement
#
# In the years 2015 to 2017, City Hotel and Resort Hotel have seen high cancellation rates. Each hotel is dealing with a number of issues as a result, including fewer revenues and less than ideal hotel room use. Consequently, lowering cancellation rates is both hotels' primary goal in order to increase their efficiency in generating revenue, and for us to offer thorough business advice to address this problem.
#
# The analysis of hotel booking cancellations as well as other factors that have no bearing on their business and yearly revenue generation are the main topics of this report.

# %% [markdown]
# # 🏨Assumptions
# - No unusual occurrences between 2015 and 2017 will have a substantial impact on the data used.
# - The information is still current and can be used to analyze a hotel's possible plans inan efficient manner.
# - There are no unanticipated negatives to the hotel employing any advised technique.
# - The hotels are not currently using any of the suggested solutions.
# - The biggest factor affecting the effectiveness of earning income is booking cancellations.
# - Cancellations result in vacant rooms for the booked length of time.
# - Clients make hotel reservations the same year they make cancellations.

# %% [markdown]
# # 🏨Research Questions
#
# 1. What are the factors that are effecting the high hotel reservation cancellations?
# 2. How can we make hotel reservations cancellations better?
# 3. How will hotels be assisted in making pricing and promotional decisions?

# %% [markdown]
# # 🏨Hypothesis
#
# 1. More cancellations occur when price is higher.
# 2. When there is a longer waiting list, customers tend to cancel more frequently.
# 3. The majority of the clients are coming from offline travel agents to make their reservations.

# %% [markdown]
# # 🏨Importing Libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # 🏨Loading the Dataset

# %%
# Set the max_columns option to None to display all columns
pd.set_option('display.max_columns', None)
df = pd.read_csv('hotel_booking.csv')

# %% [markdown]
# # 🏨Descriptive Data Analysis and Data Cleaning

# %%
df.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  children  babies  \
# 0                        0                     0       2       0.0       0
# ...

# %%
df.tail()
# Out:
#              hotel  is_canceled  lead_time  arrival_date_year  \
# 119385  City Hotel            0         23               2017
# 119386  City Hotel            0        102               2017
# 119387  City Hotel            0         34               2017
# 119388  City Hotel            0        109               2017
# 119389  City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 119385             August                        35
# 119386             August                        35
# 119387             August                        35
# 119388             August                        35
# 119389             August                        35
#
#         arrival_date_day_of_month  stays_in_weekend_nights  \
# 119385                         30                        2
# 119386                         31                        2
# 119387                         31                        2
# ...

# %%
df.shape
# Out:
# (119390, 36)

# %% [markdown]
# #### Removing the columns that contains personal details of customers

# %%
df.drop(['name', 'email', 'phone-number', 'credit_card'], axis=1, inplace=True)

# %%
df.columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type', 'agent',
#        'company', 'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %%
# Converting the column 'reservation_status_date' to datetime
df['reservation_status_date'] = pd.to_datetime(df['reservation_status_date'])

# %%
# Checking for duplicate columns
df.duplicated().any()
# Out:
# True

# %%
# Summary statisitcs of object datatypes
df.describe(include='object')
# Out:
#              hotel arrival_date_month    meal country market_segment  \
# count       119390             119390  119390  118902         119390
# unique           2                 12       5     177              8
# top     City Hotel             August      BB     PRT      Online TA
# freq         79330              13877   92310   48590          56477
#
#        distribution_channel reserved_room_type assigned_room_type  \
# count                119390             119390             119390
# unique                    5                 10                 12
# top                   TA/TO                  A                  A
# freq                  97870              85994              74053
#
#        deposit_type customer_type reservation_status
# count        119390        119390             119390
# unique            3             4                  3
# top      No Deposit     Transient          Check-Out
# freq         104641         89613              75166

# %%
# Exploring all the unique values in the object datatype columns.
for col in df.describe(include='object').columns:
    print(col)
    print(df[col].unique())
    print('-'*80)
# Out:
# hotel
# ['Resort Hotel' 'City Hotel']
# --------------------------------------------------------------------------------
# arrival_date_month
# ['July' 'August' 'September' 'October' 'November' 'December' 'January'
#  'February' 'March' 'April' 'May' 'June']
# --------------------------------------------------------------------------------
# meal
# ['BB' 'FB' 'HB' 'SC' 'Undefined']
# --------------------------------------------------------------------------------
# country
# ['PRT' 'GBR' 'USA' 'ESP' 'IRL' 'FRA' nan 'ROU' 'NOR' 'OMN' 'ARG' 'POL'
#  'DEU' 'BEL' 'CHE' 'CN' 'GRC' 'ITA' 'NLD' 'DNK' 'RUS' 'SWE' 'AUS' 'EST'
#  'CZE' 'BRA' 'FIN' 'MOZ' 'BWA' 'LUX' 'SVN' 'ALB' 'IND' 'CHN' 'MEX' 'MAR'
#  'UKR' 'SMR' 'LVA' 'PRI' 'SRB' 'CHL' 'AUT' 'BLR' 'LTU' 'TUR' 'ZAF' 'AGO'
#  'ISR' 'CYM' 'ZMB' 'CPV' 'ZWE' 'DZA' 'KOR' 'CRI' 'HUN' 'ARE' 'TUN' 'JAM'
#  'HRV' 'HKG' 'IRN' 'GEO' 'AND' 'GIB' 'URY' 'JEY' 'CAF' 'CYP' 'COL' 'GGY'
# ...

# %%
# Displaying the count of null values in each column 
df.isnull().sum()
# Out:
# hotel                                  0
# is_canceled                            0
# lead_time                              0
# arrival_date_year                      0
# arrival_date_month                     0
# arrival_date_week_number               0
# arrival_date_day_of_month              0
# stays_in_weekend_nights                0
# stays_in_week_nights                   0
# adults                                 0
# children                               4
# babies                                 0
# meal                                   0
# country                              488
# market_segment                         0
# distribution_channel                   0
# is_repeated_guest                      0
# previous_cancellations                 0
# previous_bookings_not_canceled         0
# reserved_room_type                     0
# assigned_room_type                     0
# booking_changes                        0
# deposit_type                           0
# ...

# %%
# Removing the columns with most null values
df.drop(['agent','company'], axis=1, inplace=True)

# Removing rows with null values
df.dropna(inplace=True)

# %%
# Conforming that there are no more null values
df.isnull().sum()
# Out:
# hotel                             0
# is_canceled                       0
# lead_time                         0
# arrival_date_year                 0
# arrival_date_month                0
# arrival_date_week_number          0
# arrival_date_day_of_month         0
# stays_in_weekend_nights           0
# stays_in_week_nights              0
# adults                            0
# children                          0
# babies                            0
# meal                              0
# country                           0
# market_segment                    0
# distribution_channel              0
# is_repeated_guest                 0
# previous_cancellations            0
# previous_bookings_not_canceled    0
# reserved_room_type                0
# assigned_room_type                0
# booking_changes                   0
# deposit_type                      0
# days_in_waiting_list              0
# customer_type                     0
# adr                               0
# ...

# %%
df.describe()
# Out:
#          is_canceled      lead_time  arrival_date_year  \
# count  118898.000000  118898.000000      118898.000000
# mean        0.371352     104.311435        2016.157656
# std         0.483168     106.903309           0.707459
# min         0.000000       0.000000        2015.000000
# 25%         0.000000      18.000000        2016.000000
# 50%         0.000000      69.000000        2016.000000
# 75%         1.000000     161.000000        2017.000000
# max         1.000000     737.000000        2017.000000
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count             118898.000000              118898.000000
# mean                  27.166555                  15.800880
# std                   13.589971                   8.780324
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   28.000000                  16.000000
# ...

# %% [markdown]
# **Removing Outliers**:
#
# The `adr`(average daily rate) column in which we are going to perform our analysis seem to have outliers. Let's look at the outliers via a boxplot visual.

# %%
df['adr'].plot(kind='box')
# Out:
# <Axes: >

# %%
# Removing outlier
df = df[df['adr'] < 5000]

# %%
df.describe()
# Out:
#          is_canceled      lead_time  arrival_date_year  \
# count  118897.000000  118897.000000      118897.000000
# mean        0.371347     104.312018        2016.157657
# std         0.483167     106.903570           0.707462
# min         0.000000       0.000000        2015.000000
# 25%         0.000000      18.000000        2016.000000
# 50%         0.000000      69.000000        2016.000000
# 75%         1.000000     161.000000        2017.000000
# max         1.000000     737.000000        2017.000000
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count             118897.000000              118897.000000
# mean                  27.166674                  15.800802
# std                   13.589966                   8.780321
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   28.000000                  16.000000
# ...

# %% [markdown]
# # 🏨Exploratory Data Analysis and Visualizations

# %%
# Correlation between numerical columns
co = df.corr(numeric_only = True)
sns.heatmap(co, cmap='coolwarm')
# Out:
# <Axes: >

# %% [markdown]
# - `is_cancelled` shows weak positive correlation with `lead_time`.
# - `is_repeated_guest` shows weak positive correlated to `previous_booking_not_canceled`.
# - `is_canceled` has mild negative correlation with `total_of_special_requests`, meaning more requests lead to fewer cancellations.
# - `adr` shows weak positive correlation with `children`, meaning rates are hgih during family vacations.

# %% [markdown]
# ### Finding booking cancellation percentge

# %%
cancelled_perc = df['is_canceled'].value_counts(normalize=True)
cancelled_perc
# Out:
# 0    0.628653
# 1    0.371347
# Name: is_canceled, dtype: float64

# %%
ax = sns.countplot(data=df, x='is_canceled', palette='Blues')
ax.set_title('Reservation Status Count', size=15)
ax.set_xticklabels(['Not Cancelled', 'Cancelled'])
ax.set_xlabel('')
ax.set_ylabel('')
plt.show()

# %% [markdown]
# ### Finding cancellation status with respect to hotels

# %%
plt.figure(figsize=(10,4))
ax = sns.countplot(x = 'hotel', hue='is_canceled', data = df, palette = 'Blues')
plt.title('Reservation Status in Different Hotels', size=15)
plt.ylabel('Number of Bookings')
plt.legend(['Not Canceled','Canceled'])
ax.set_xlabel('')
ax.set_ylabel('')
plt.show()

# %%
resort = df[df['hotel'] == 'Resort Hotel']
resort['is_canceled'].value_counts(normalize=True)
# Out:
# 0    0.72025
# 1    0.27975
# Name: is_canceled, dtype: float64

# %% [markdown]
# **Resort Hotel cancellation status**
# - **Not Cancelled** : 0.72025
# - **Cancelled** : 0.27975

# %%
city = df[df['hotel'] == 'City Hotel']
city['is_canceled'].value_counts(normalize=True)
# Out:
# 0    0.582918
# 1    0.417082
# Name: is_canceled, dtype: float64

# %% [markdown]
# **City Hotel cancelletion status**
# - **Not Cancelled** : 0.582918
# - **Cancelled** : 0.417082

# %% [markdown]
# **Findings** -
# The cancellation rates are higher in `City Hotels` as compared to `Resort Hotels`.
#
# Now we will try to find the reason why?
# We will anylize the `adr` column which is `average daily rate` to examine whether `Price` has any effect on the cancellations.

# %% [markdown]
# ### Visualizing Average daily rate (adr) of City and Resort hotels.
# The Average Daily Rate (ADR) is a key performance indicator that represents the average room rate that a guest pays per room per day. It is calculated by dividing the total room revenue by the total number of rooms sold over a specific period.
# ![img](https://duve.com/wp-content/uploads/2022/10/adr-formula.jpg)

# %%
#Filtereing the data for resort and city hotels separately
resort = resort.groupby('reservation_status_date')[['adr']].mean()
city = city.groupby('reservation_status_date')[['adr']].mean()

# %% [markdown]
# ## Creating an Average Daily Rate Visualization of both City and Resort Hotels

# %%
plt.figure(figsize=(20,8))
plt.title('Average Daily Rate in City and Resort Hotels', fontsize = 30)
plt.plot(resort.index, resort['adr'], label = 'Resort Hotel')
plt.plot(city.index, city['adr'], label = 'City Hotel')
plt.legend(fontsize = 20)
plt.show()

# %% [markdown]
# - The City hotels price seems to fluctuate less in comparison to Resort hotels.
# - For the most part City hotel prices are lower than Resort hotels. But some days it is vice-versa.
# - Both City and Resort hotel seem to have spikes which could be the price hike on weekends or monthends.

# %% [markdown]
# ### Monthly Reservation Status

# %%
df['month'] = df['reservation_status_date'].dt.month # Creating the month column
plt.figure(figsize = (16,8))
sns.countplot(x = 'month', hue = 'is_canceled', data = df, palette = 'bright')
plt.title('Monthly Reservation Status', fontsize = 25)
plt.xlabel('Month', fontsize = 15)
plt.ylabel('Number of Reservations', fontsize = 15)
plt.legend(['Not canceled', 'Canceled'])
plt.show()

# %% [markdown]
# - Highest cancellations: January
# - Lowest cancellations: August
# - Highest reservations: August
# - Lowest reservations: December

# %% [markdown]
# ## Monthly Reservation Status for City and Resort Hotels

# %%
city_hotel = df[df['hotel'] == 'City Hotel']
resort_hotel = df[df['hotel'] == 'Resort Hotel']

# %%
plt.figure(figsize=(16,8))
sns.countplot(data = resort_hotel, x='month', hue = 'is_canceled', palette = 'Greens')
plt.title('Month Reservation Status for Resort Hotels', size = 20)
plt.xlabel('Month')
plt.ylabel('Number of reservations')
plt.legend(['Not Canceled', 'Canceled'])
plt.show()

# %% [markdown]
# ### Resort hotel reservation status w.r.t. months
# - Highest cancellations: January
# - Lowest cancellations: September
# - Highest reservations: August
# - Lowest reservations: December

# %%
plt.figure(figsize=(16,8))
sns.countplot(data = city_hotel, x='month', hue = 'is_canceled', palette = 'Purples')
plt.title('Monthly Reservation Status of City Hotels', size = 20)
plt.xlabel('Month')
plt.ylabel('Number of reservations')
plt.legend(['Not Canceled', 'Canceled'])
plt.show()

# %% [markdown]
# ### City hotel reservation status w.r.t. months
# - Highest cancellations: January
# - Lowest cancellations: June
# - Highest reservations: August
# - Lowest reservations: December

# %% [markdown]
# ## ADR by Month for Canceled Reservation only

# %%
cancelled_city = df[(df['is_canceled'] == 1) & (df['hotel'] == 'City Hotel')].groupby('month')[['adr']].sum().reset_index()

# %%
plt.figure(figsize=(16,8))
sns.barplot(data = cancelled_city, x='month', y='adr', palette = 'Reds')
plt.title('Monthly ADR for City Hotels', size = 20)
plt.show()

# %% [markdown]
# #### City Hotel ADR Status
# - Highest ADR: January
# - Lowest ADR: June & August

# %%
cancelled_resort = df[(df['is_canceled'] == 1) & (df['hotel'] == 'Resort Hotel')].groupby('month')[['adr']].sum().reset_index()

# %%
plt.figure(figsize=(16,8))
sns.barplot(data = cancelled_resort, x='month', y='adr', palette ='Greens')
plt.title('Month ADR for Resort Hotels', size = 20)
plt.show()

# %% [markdown]
# #### Resort Hotel ADR Status
# - Highest ADR : June & July
# - Lowest ADR : September

# %% [markdown]
# ### Conclusion
# - For city hotels, high adr leads to higher cancellations.
# - For resort hotels, cancellations is not related to adr.

# %% [markdown]
# ## Cancelled Vs Not Cancelled ADR

# %%
cancelled_df_adr = df[df['is_canceled'] == 1].groupby('reservation_status_date')[['adr']].mean().reset_index()
not_cancelled_df_adr = df[df['is_canceled'] == 0].groupby('reservation_status_date')[['adr']].mean().reset_index()

# %%
plt.figure(figsize=(20, 8))
plt.title('Average Daily Rate', size = 25)
plt.plot(cancelled_df_adr['reservation_status_date'], cancelled_df_adr['adr'], label = 'Cancelled')
plt.plot(not_cancelled_df_adr['reservation_status_date'], not_cancelled_df_adr['adr'], label = 'Not Cancelled')
plt.legend(fontsize = 15)
plt.show()

# %% [markdown]
# The visualization looks messy as the data is widespread. We will filter the data to get a better visual.

# %%
cancelled_df_adr = df[(df['is_canceled'] == 1) & (df['reservation_status_date'] > '2016')].groupby('reservation_status_date')[['adr']].mean().reset_index()
not_cancelled_df_adr = df[(df['is_canceled'] == 0) & (df['reservation_status_date'] > '2016')].groupby('reservation_status_date')[['adr']].mean().reset_index()

# %%
plt.figure(figsize=(20,8))
plt.title('Average Daily Rate', size = 25)
plt.plot(cancelled_df_adr['reservation_status_date'], cancelled_df_adr['adr'], label = 'Cancelled')
plt.plot(not_cancelled_df_adr['reservation_status_date'], not_cancelled_df_adr['adr'], label = 'Cancelled')
plt.show()

# %% [markdown]
# ### Conclusion
# - Overall high cancellations when prices are high.
# - The cancelled data is higher when compared to not cancelled data for the most part in terms of average daily rate.
# - This proves that the average daily rate is heavily influencing the high cancellation rates.
# - The spikes we observe are nothing but weekend or month end price hikes.

# %% [markdown]
# ## Finding Cancellation Reason for Resorts
# Is higher cencellations related to `lead_time` in resorts ?

# %%
resort = df[df['hotel'] == 'Resort Hotel']
resort.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  children  babies  \
# 0                        0                     0       2       0.0       0
# ...

# %%
resort_cancelled = resort[(resort['is_canceled'] == 1) & (resort['reservation_status_date'] > '2016')].groupby('reservation_status_date')[['lead_time']].mean().reset_index()
resort_not_cancelled = resort[(resort['is_canceled'] == 0) & (resort['reservation_status_date'] > '2016')].groupby('reservation_status_date')[['lead_time']].mean().reset_index()

# %%
plt.figure(figsize=(20,5))
plt.title('Reservation Status W.R.T Lead Time', size = 25)
plt.plot(resort_cancelled['reservation_status_date'], resort_cancelled['lead_time'], label = 'Cancelled')
plt.plot(resort_not_cancelled['reservation_status_date'], resort_not_cancelled['lead_time'], label = 'Not Cancelled')
plt.ylabel('Lead Time', size=15)
plt.legend(fontsize = 10)
plt.show()

# %% [markdown]
# **Findings**
#
# Longer lead time are leading to more cancellations in resort hotels

# %%
cancelled_wl = resort[(resort['is_canceled'] == 1) & (resort['reservation_status_date'] > '2016')].groupby('reservation_status_date')[['days_in_waiting_list']].mean().reset_index()
not_cancelled_wl = resort[(resort['is_canceled'] == 0) & (resort['reservation_status_date'] > '2016')].groupby('reservation_status_date')[['days_in_waiting_list']].mean().reset_index()

# %%
plt.figure(figsize=(20,6))
plt.title('Reservatioin Status W.R.T Waiting List', size = 25)
plt.plot(cancelled_wl['reservation_status_date'], cancelled_wl['days_in_waiting_list'], label = 'Cancelled')
plt.plot(not_cancelled_wl['reservation_status_date'], not_cancelled_wl['days_in_waiting_list'], label = 'Not Cancelled')
plt.legend(fontsize = 15)
plt.ylabel('Number of Days', size = 15)
plt.xlabel('Reservation Satus Date', size = 15)
plt.show()

# %% [markdown]
# ### Findings
# Longer waiting list has no result in higher cancellation rates

# %% [markdown]
# # Countrywise Cancellation Rate

# %%
cancelled_data = df[df['is_canceled'] == 1]
top_10_country = cancelled_data['country'].value_counts()[:10]
top_10_country
# Out:
# PRT    27514
# GBR     2453
# ESP     2177
# FRA     1934
# ITA     1333
# DEU     1218
# IRL      832
# BRA      830
# USA      501
# BEL      474
# Name: country, dtype: int64

# %%
colors = sns.color_palette('Set2')
plt.figure(figsize=(8,8))
plt.title('Top 10 Countries With Reservation Cancelled')
plt.pie(top_10_country, autopct = '%.2f', labels = top_10_country.index, startangle = 140, colors = colors)
plt.show()

# %% [markdown]
# `Portugal` has the highest number of cancellations.

# %% [markdown]
# ## Distribution of Market Segment

# %%
df['market_segment'].value_counts()
# Out:
# Online TA        56402
# Offline TA/TO    24159
# Groups           19806
# Direct           12448
# Corporate         5111
# Complementary      734
# Aviation           237
# Name: market_segment, dtype: int64

# %%
df['market_segment'].value_counts(normalize=True)
# Out:
# Online TA        0.474377
# Offline TA/TO    0.203193
# Groups           0.166581
# Direct           0.104696
# Corporate        0.042987
# Complementary    0.006173
# Aviation         0.001993
# Name: market_segment, dtype: float64

# %%
cancelled_data['market_segment'].value_counts(normalize=True)
# Out:
# Online TA        0.469696
# Groups           0.273985
# Offline TA/TO    0.187466
# Direct           0.043486
# Corporate        0.022151
# Complementary    0.002038
# Aviation         0.001178
# Name: market_segment, dtype: float64

# %% [markdown]
# ### Finding
# 47% booking from online medium
# ### Suggestions
# - Provide accurate photos of hotel to reduce cancellations.
# - Utilize a reliable online booking platform that allows guests to make reservations easily. Provide high-quality photos and detailed descriptions of properties.
# - Stay competitive with your pricing while maintaining the quality of the services. Offer promotions, discounts, and loyalty - programs to attract repeat customers.
# - Encourage satisfied guests to leave positive reviews on platforms like TripAdvisor, Yelp, or Google Reviews. Respond to reviews, whether positive or negative, to show the commitment to customer satisfaction.
# - Use social media platforms to promote your hotel and engage with potential guests. Share high-quality images, updates, and special offers.

# %% [markdown]
# ### Hotel Type Preference

# %%
df['total_child'] = df['children'] + df['babies']
sns.pairplot(data = df[df['adr']<500][['hotel','adr', 'total_child']], hue='hotel')
plt.show()

# %% [markdown]
# - Families with kids prefer city hotels over resorts.
# - Tourists without kids prefer resorts. This may include group of friends, couples, solo travellers.
#
# ### Suggestion
# - Recognizing that City Hotel is the top choice for families traveling with their little ones is truly heartwarming. This valuable insight inspires us to go the extra mile in celebrating and enriching the family-friendly offerings and adventures at the City Hotel, ensuring that we create unforgettable moments for families planning their special getaways.
# - To enhance the resort hotel experience for a target demographic of adult tourists without children, a strategic approach can be adopted to create a more couple-friendly and friends-friendly environment, catering to the preferences and needs of this specific market segment.

# %% [markdown]
# ### Room Type Preference

# %%
sns.set_style('ticks')
sns.boxenplot(data = df[df['adr']<500], x='reserved_room_type', y='adr', hue='arrival_date_year', width=0.8)
plt.xlabel('Reserved Room Type', fontsize=12)
plt.xticks(fontsize=18)
plt.ylabel('Rate', fontsize=12)
plt.yticks(fontsize=18)
plt.legend(loc=(1.05,0))
plt.show()

# %% [markdown]
# - C, G, H are most preferred.
# - A, D, B are least preferred.
#
# ### Suggestion
# Room Upgrades: Consider offering room upgrades to guests who book less popular room types. This can be a way to upsell and generate more revenue. Make sure to highlight the benefits of the upgraded room.

# %% [markdown]
# # 🏨Summary and Conclusion
#
# 1. Strategic Pricing Adjustments: Cancellation rates tend to increase as room prices rise. To mitigate cancellations, hotels can optimize their pricing strategies by offering location-based discounts and special consumer incentives.
#
# 2. Weekend and Holiday Discounts: Resort hotels experience a higher cancellation-to-booking ratio compared to city hotels. To address this, hotels should consider offering competitive discounts on room rates during weekends and holidays.
#
# 3. January Revenue Boost Campaign: In the month of January, hotels can initiate revenue-boosting campaigns and marketing efforts at reasonable price points. This is especially valuable, given that January tends to have the highest cancellation rates.
#
# 4. Early Bird Benefits: Offer discounts or perks for guests who book in advance, encouraging early reservations.
#
# 5. Enhanced Quality and Service in Portugal: To reduce cancellation rates, hotels, particularly in Portugal, can focus on elevating the quality of their accommodations and services. This strategy aims to enhance guest satisfaction and loyalty,resulting in fewer cancellations.
#
# 6. Effective Cancellation Management: Recognizing the emerging trend of post-cancellation payments, viewed as an opportunity to turn challenges into advantages from a business standpoint, we can effectively leverage this situation. By employing astute strategies aimed at reducing cancellations, including transparent terms and conditions, considerate reminders, and potentially introducing incentives for guests committed to their reservations, we can create a win-win scenario. This approach not only enhances the guest experience but also guarantees a consistent revenue flow for the business.

# %% [markdown]
# # 🏨THE END
